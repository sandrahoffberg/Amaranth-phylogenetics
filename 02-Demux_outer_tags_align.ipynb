# %% [markdown]
# ## This notebook is different than 2.1 because this includes demux outer at the top and the MIGseq reads

# %%
# import packages into python
import ipyrad as ip
import ipyparallel as ipp
import ipyrad.analysis as ipa
import pandas as pd

# connect to parallel client
ipyclient = ipp.Client()
ip.cluster_info(ipyclient)

# print the version of ipyrad you are running
print('ipyrad', ipa.__version__)
# Out:
# Parallel connection | t103: 24 cores
# ipyrad 0.9.26

# %%
#Read in data and barcodes that are already created

COL_plates = "/moto/eaton/projects/RAW_DATA/Amaranthus/Amaranthus_COL_3RAD_run2_R*_.fastq.gz"
TUB_plate = "/moto/eaton/users/slh2181/tuberculatus_plate/Run_191713587/bcl2fastq2/Undetermined_S0_R*_001.fastq.gz"

BARCODES_I7_plate12 = "/moto/eaton/projects/RAW_DATA/Amaranthus/Amaranthus_COL_3RAD_run2_i7_barcodes.txt"
BARCODES_I7_tuberculatus = "/moto/eaton/users/slh2181/tuberculatus_plate/ipyrad/i7_barcodes_tub.txt"

INNER_BARCODES_plate1 = "/moto/eaton/users/slh2181/tuberculatus_plate/ipyrad/Amaranthus_UGA_3RAD_plate1_inline_barcodes.txt"
INNER_BARCODES_plate2 = "/moto/eaton/projects/RAW_DATA/Amaranthus/Amaranthus_COL_3RAD_plate2_inline_barcodes.txt"
INNER_BARCODES_plate3 = "/moto/eaton/users/slh2181/tuberculatus_plate/ipyrad/inner_barcodes_tub.txt"

QUINOA = "/moto/eaton/projects/demux/digested_genomes/*.gz"

# the reference Amaranthus genome
REF1 = "/moto/eaton/users/slh2181/reference/Ahypochondriacus_459_v2.0.fa"

# the reference Quinoa genome
REF2 = "/moto/eaton/projects/demux/quinoa.fna"

# %%
! cat $BARCODES_I7_tuberculatus
# Out:
# Amaranthus_tuberculatus_3RAD	CTCGTCTT
# MIGseq1a	ATGACCAG
# MIGseq1b	AACCGTTC
# MIGseq1c	TCCAATCG
# MIGseq1d	CTGCACTT
# MIGseq1e	CGCTTAAC
# MIGseq1f	CACCACTA
# MIGseq1g	ACAGCAAC
# MIGseq1h	GGAAGGAT
# MIGseq2a	CGATAGAG
# MIGseq2b	TTCGTTGG
# MIGseq2c	TGGAGAGT
# MIGseq2d	TCAGACGA
# MIGseq2e	GACGAATG
# MIGseq2f	CATGAGGA
# MIGseq2g	CGGTTGTT
# MIGseq2h	TCCGTATG
# Pedicularis_plate1	CGAACTGT
# Pedicularis_plate2	TCGGTTAC

# %%
! cat $BARCODES_I7_plate12
# Out:
# plate1	CGAACTGT
# plate1	CATTCGGT
# plate1	AAGTCGAG
# plate1	TATCGGTC
# plate1	GTATTGGC
# plate1	AACCTCCT
# plate2	CTCGTCTT
# plate2	TCGGTTAC
# plate2	TATTCGCC
# plate2	AGTCGCTT
# plate2	TGGCACTA
# plate2	GGTTGTCA

# %%
! head -n 10 $INNER_BARCODES_plate1
# Out:
# SLH_AL_0001	CCGAAT   	CTAACG
# SLH_AL_0003	TTAGGCA	    CTAACG
# SLH_AL_0004	AACTCGTC	CTAACG
# SLH_AL_0006	GGTCTACGT	CTAACG
# SLH_AL_0009	GATACC		CTAACG
# SLH_AL_0010	AGCGTTG	    CTAACG
# SLH_AL_0013	CTGCAACT	CTAACG
# SLH_AL_0017	TCATGGTCA	CTAACG
# SLH_AL_0018	CCGAAT  	TCGGTAC
# SLH_AL_0019	TTAGGCA	    TCGGTAC

# %%
! head -n 10 $INNER_BARCODES_plate2
# Out:
# SLH_AL_0101-contemp	CCGAAT	CTAACG
# SLH_AL_0012-contemp	TTAGGCA	CTAACG
# SLH_AL_0095-contemp	AACTCGTC	CTAACG
# SLH_AL_0072-contemp	GGTCTACGT	CTAACG
# SLH_AL_0064-contemp	GATACC	CTAACG
# SLH_AL_0077-contemp	AGCGTTG	CTAACG
# SLH_AL_0104-contemp	CTGCAACT	CTAACG
# SLH_AL_0036-contemp	TCATGGTCA	CTAACG
# SLH_AL_0090-contemp	CCGAAT	TCGGTAC
# SLH_AL_0027-contemp	TTAGGCA	TCGGTAC

# %%
# This is to demultiplex plate 1 from plate 2 when they were sequenced in Bendesky lab @ Columbia in eary 2019
demux_outer1 = ip.Assembly("demux_i7s")
demux_outer1.params.project_dir = "/moto/eaton/users/slh2181/tuberculatus_plate/ipyrad"
demux_outer1.params.barcodes_path = BARCODES_I7_plate12
demux_outer1.params.raw_fastq_path = COL_plates
demux_outer1.params.datatype = "pairddrad"
demux_outer1.params.restriction_overhang = ("ATCGG", "TAGCTT")

# important: set hackers params to tell it to demux on i7 
demux_outer1.hackersonly.demultiplex_on_i7_tags = True
demux_outer1.hackersonly.merge_technical_replicates = True
# Out:
# New Assembly: demux_i7s
# Warning: technical replicates (same name) present.

# %%
# run demultiplexing, this takes ~40 mins with 24 cores
demux_outer1.run('1', auto=True, force=True)
# Out:
# Parallel connection | t103: 24 cores
# Warning: technical replicates (same name) present.
# [####################] 100% 0:36:18 | sorting reads        | s1 |
# [####################] 100% 0:05:22 | writing/compressing  | s1 |

# %%
# show demux i7 stats
demux_outer1.stats
# Out:
#         state  reads_raw
# plate1      1   71586332
# plate2      1   25966588

# %%
# This is to demultiplex A. tuberculatus from Peducularis plates that were sequenced at Admera in Nov 2019
demux_outer2 = ip.Assembly("demux_tub")
demux_outer2.params.project_dir = "/moto/eaton/users/slh2181/tuberculatus_plate/ipyrad"
demux_outer2.params.barcodes_path = BARCODES_I7_tuberculatus
demux_outer2.params.raw_fastq_path = TUB_plate
demux_outer2.params.datatype = "pairddrad"
#demux_outer2.params.restriction_overhang = ("ATCGG", "TAGCTT") #Pedicularis is different and this shouldn't be needed

# important: set hackers params to tell it to demux on i7 
demux_outer2.hackersonly.demultiplex_on_i7_tags = True
demux_outer2.hackersonly.merge_technical_replicates = True   #use this if you have the same sample with different barcodes
# Out:
# New Assembly: demux_tub

# %%
demux_outer2.params
# Out:
# 0   assembly_name               demux_tub
# 1   project_dir                 ./ipyrad
# 2   raw_fastq_path              ./Run_191713587/bcl2fastq2/Undetermined_S0_R*_001.fastq.gz
# 3   barcodes_path               ./ipyrad/i7_barcodes_tub.txt
# 4   sorted_fastq_path
# 5   assembly_method             denovo
# 6   reference_sequence
# 7   datatype                    pairddrad
# 8   restriction_overhang        ('TGCAG', '')
# 9   max_low_qual_bases          5
# 10  phred_Qscore_offset         33
# 11  mindepth_statistical        6
# 12  mindepth_majrule            6
# 13  maxdepth                    10000
# 14  clust_threshold             0.85
# 15  max_barcode_mismatch        0
# 16  filter_adapters             0
# 17  filter_min_trim_len         35
# 18  max_alleles_consens         2
# 19  max_Ns_consens              0.05
# 20  max_Hs_consens              0.05
# 21  min_samples_locus           4
# 22  max_SNPs_locus              0.2
# 23  max_Indels_locus            8
# 24  max_shared_Hs_locus         0.5
# 25  trim_reads                  (0, 0, 0, 0)
# 26  trim_loci                   (0, 0, 0, 0)
# 27  output_formats              ['p', 's', 'l']
# 28  pop_assign_file
# 29  reference_as_filter

# %%
# run demultiplexing, this takes 60 mins
demux_outer2.run('1', auto=True, force=True)
# Out:
# Parallel connection | t103: 24 cores
# [####################] 100% 0:36:14 | chunking large files | s1 | s1 |
# [####################] 100% 0:17:07 | sorting reads        | s1 |
# [####################] 100% 0:15:27 | writing/compressing  | s1 |

# %%
# show demux i7 stats 
demux_outer2.stats
#Amaranthus_tuberculatus_3RAD	1	133729311
# Out:
#                               state  reads_raw
# Amaranthus_tuberculatus_3RAD      1  133729311
# MIGseq1a                          1      45608
# MIGseq1b                          1      46139
# MIGseq1c                          1      46716
# MIGseq1d                          1      40656
# MIGseq1e                          1      44530
# MIGseq1f                          1      44527
# MIGseq1g                          1      59566
# MIGseq1h                          1      39801
# MIGseq2a                          1      42456
# MIGseq2b                          1      44795
# MIGseq2c                          1      33600
# MIGseq2d                          1      42055
# MIGseq2e                          1      43975
# MIGseq2f                          1      39371
# MIGseq2g                          1      46674
# MIGseq2h                          1      46363
# Pedicularis_plate1                1  198248811
# Pedicularis_plate2                1  119356646

# %%
#Is this the same when I include the correct RE overhang?
demux_outer2.params.restriction_overhang = ("ATCGG", "TAGCTT") #Pedicularis is different and this shouldn't be needed
demux_outer2.params
# Out:
# 0   assembly_name               demux_tub
# 1   project_dir                 ./ipyrad
# 2   raw_fastq_path              ./Run_191713587/bcl2fastq2/Undetermined_S0_R*_001.fastq.gz
# 3   barcodes_path               ./ipyrad/i7_barcodes_tub.txt
# 4   sorted_fastq_path
# 5   assembly_method             denovo
# 6   reference_sequence
# 7   datatype                    pairddrad
# 8   restriction_overhang        ('ATCGG', 'TAGCTT')
# 9   max_low_qual_bases          5
# 10  phred_Qscore_offset         33
# 11  mindepth_statistical        6
# 12  mindepth_majrule            6
# 13  maxdepth                    10000
# 14  clust_threshold             0.85
# 15  max_barcode_mismatch        0
# 16  filter_adapters             0
# 17  filter_min_trim_len         35
# 18  max_alleles_consens         2
# 19  max_Ns_consens              0.05
# 20  max_Hs_consens              0.05
# 21  min_samples_locus           4
# 22  max_SNPs_locus              0.2
# 23  max_Indels_locus            8
# 24  max_shared_Hs_locus         0.5
# 25  trim_reads                  (0, 0, 0, 0)
# 26  trim_loci                   (0, 0, 0, 0)
# 27  output_formats              ['p', 's', 'l']
# 28  pop_assign_file
# 29  reference_as_filter

# %%
# run demultiplexing, this takes 60 mins
demux_outer2.run('1', auto=True, force=True)
# Out:
# Parallel connection | t103: 24 cores
# [####################] 100% 0:36:06 | chunking large files | s1 | s1 |
# [####################] 100% 0:18:33 | sorting reads        | s1 |
# [####################] 100% 0:15:31 | writing/compressing  | s1 |

# %%
demux_outer2.stats
# Out:
#                               state  reads_raw
# Amaranthus_tuberculatus_3RAD      1  133729311
# MIGseq1a                          1      45608
# MIGseq1b                          1      46139
# MIGseq1c                          1      46716
# MIGseq1d                          1      40656
# MIGseq1e                          1      44530
# MIGseq1f                          1      44527
# MIGseq1g                          1      59566
# MIGseq1h                          1      39801
# MIGseq2a                          1      42456
# MIGseq2b                          1      44795
# MIGseq2c                          1      33600
# MIGseq2d                          1      42055
# MIGseq2e                          1      43975
# MIGseq2f                          1      39371
# MIGseq2g                          1      46674
# MIGseq2h                          1      46363
# Pedicularis_plate1                1  198248811
# Pedicularis_plate2                1  119356646

# %%
RAW_DATA_UGA =    "/moto/eaton/projects/RAW_DATA/Amaranthus/Amaranthus_UGA_3RAD_*.gz"
RAW_DATA_plate1 = "/moto/eaton/users/slh2181/tuberculatus_plate/ipyrad/demux_i7s_fastqs/plate1_*.gz"
RAW_DATA_plate2 = "/moto/eaton/users/slh2181/tuberculatus_plate/ipyrad/demux_i7s_fastqs/plate2_*.gz"
RAW_DATA_plate3 = "/moto/eaton/users/slh2181/tuberculatus_plate/ipyrad/demux_tub_fastqs/Amaranthus_*.gz"

# %%
# digest the quinoa genome and write as fastq data
dg = ipa.digest_genome(
    fasta="/moto/eaton/projects/demux/quinoa.fna.gz",
    name="quinoa",
    workdir="/moto/eaton/users/slh2181/tuberculatus_plate/ipyrad/quinoa4",
    re1="AAGCTT",
    re2="CCGG",
    paired=True,
    min_size=200,
    max_size=1000,
    ncopies=10,
    readlen=150,
    #nscaffolds=20,
)
dg.run()


# digest the quinoa genome and write as fastq data
dg2 = ipa.digest_genome(
    fasta="/moto/eaton/users/slh2181/reference/beet/GCF_000511025.2_RefBeet-1.2.2_genomic.fna.gz",
    name="beet",
    workdir="/moto/eaton/users/slh2181/tuberculatus_plate/ipyrad/beet4",
    re1="AAGCTT",
    re2="CCGG",
    paired=True,
    min_size=200,
    max_size=1000,
    ncopies=10,
    readlen=150,
    #nscaffolds=20,
)
dg2.run()
# Out:
# extracted 281471 reads
# extracted 110308 reads

# %%
lib5 = ip.Assembly("quinoa")              #This is quinoa digested reference
lib5.params.sorted_fastq_path = "/moto/eaton/users/slh2181/tuberculatus_plate/ipyrad/quinoa4/quinoa_*.gz"
lib5.params.datatype = "pair3rad"
lib5.params.project_dir = "/moto/eaton/users/slh2181/tuberculatus_plate/ipyrad/quinoa_ref4"
lib5.params.restriction_overhang = ("ATCGG", "TAGCTT")


lib6 = ip.Assembly("beet")              #This is beet digested reference
lib6.params.sorted_fastq_path = "/moto/eaton/users/slh2181/tuberculatus_plate/ipyrad/beet4/beet*.gz"
lib6.params.datatype = "pair3rad"
lib6.params.project_dir = "/moto/eaton/users/slh2181/tuberculatus_plate/ipyrad/beet_ref4"
lib6.params.restriction_overhang = ("ATCGG", "TAGCTT")


lib5.run('1', force=True, ipyclient=ipyclient)
lib6.run('1', force=True, ipyclient=ipyclient)
# Out:
# New Assembly: quinoa
# New Assembly: beet
# Parallel connection | t103: 24 cores
# [####################] 100% 0:00:14 | loading reads        | s1 |
# Parallel connection | t103: 24 cores
# [####################] 100% 0:00:04 | loading reads        | s1 |

# %%
# load each library from i7-demux'd fastq files
lib1 = ip.Assembly("UGA_plate1")          #This is UGA
lib1.params.raw_fastq_path = RAW_DATA_UGA
lib1.params.barcodes_path = INNER_BARCODES_plate1
lib1.params.datatype = "pair3rad"
lib1.params.project_dir = "/moto/eaton/users/slh2181/tuberculatus_plate/ipyrad/"
lib1.params.max_barcode_mismatch = 1
lib1.params.restriction_overhang = ("ATCGG", "TAGCTT")

lib2 = ip.Assembly("Columbia_plate1")     #This is Columbia plate 1
lib2.params.raw_fastq_path = RAW_DATA_plate1
lib2.params.barcodes_path = INNER_BARCODES_plate1
lib2.params.datatype = "pair3rad"
lib2.params.project_dir = "/moto/eaton/users/slh2181/tuberculatus_plate/ipyrad"
lib2.params.max_barcode_mismatch = 1
lib2.params.restriction_overhang = ("ATCGG", "TAGCTT")

lib3 = ip.Assembly("Columbia_contemp")     #This is Columbia (half) plate 2
lib3.params.raw_fastq_path = RAW_DATA_plate2
lib3.params.barcodes_path = INNER_BARCODES_plate2
lib3.params.datatype = "pair3rad"
lib3.params.project_dir = "/moto/eaton/users/slh2181/tuberculatus_plate/ipyrad"
lib3.params.max_barcode_mismatch = 1
lib3.params.restriction_overhang = ("ATCGG", "TAGCTT")

lib4 = ip.Assembly("tuberculatus")         #This is tuberculatus plate
lib4.params.raw_fastq_path = RAW_DATA_plate3
lib4.params.barcodes_path = INNER_BARCODES_plate3
lib4.params.datatype = "pair3rad"
lib4.params.project_dir = "/moto/eaton/users/slh2181/tuberculatus_plate/ipyrad"
lib4.params.max_barcode_mismatch = 1
lib4.params.restriction_overhang = ("ATCGG", "TAGCTT")

#lib5 = ip.Assembly("quinoa")              #This is quinoa digested reference
#lib5.params.sorted_fastq_path = QUINOA
#lib5.params.datatype = "pair3rad"
#lib5.params.project_dir = "/moto/eaton/users/slh2181/tuberculatus_plate/ipyrad"
#lib5.params.restriction_overhang = ("ATCGG", "TAGCTT")


# run step 1 to sort/load fastq files 
lib1.run('1', force=True, ipyclient=ipyclient)  #2 mins
lib2.run('1', force=True, ipyclient=ipyclient)  #half hr
lib3.run('1', force=True, ipyclient=ipyclient)  #10 mins
lib4.run('1', force=True, ipyclient=ipyclient)  #1 hr
#lib5.run('1', force=True, ipyclient=ipyclient)
# Out:
# New Assembly: UGA_plate1
# New Assembly: Columbia_plate1
# New Assembly: Columbia_contemp
# New Assembly: tuberculatus
# Parallel connection | t103: 24 cores
# [####################] 100% 0:01:13 | sorting reads        | s1 |
# [####################] 100% 0:00:13 | writing/compressing  | s1 |
# Parallel connection | t103: 24 cores
# [                    ]   0% 0:04:46 | sorting reads        | s1 |

# %%
# load accession:species dataframe
spnames = pd.read_csv("/moto/eaton/users/slh2181/tuberculatus_plate/ipyrad/Amaranth_sample_names_tub.csv")

# subset only rows with species names not empty
spnames = spnames[spnames.Species.notna()]

# convert dataframe to a dictionary 
ndict = {spnames.Sample[i]: spnames.Species[i] for i in spnames.index}

# combine id and spp name into one long name
for key, value in ndict.items():
    ndict[key] = value + "_" + key

# %%
# create a merged assembly
merged = ip.merge(
    name="229_samp_quinoa_beet2", 
    assemblies=[lib1, lib2, lib3, lib4, lib5, lib6],
    rename_dict=ndict,
    )
merged.save()

# %%
# set params on this assembly
merged.params.project_dir = "/moto/eaton/users/slh2181/tuberculatus_plate/ipyrad/"
merged.params.assembly_method = "reference"
merged.params.reference_sequence = REF1
merged.params.restriction_overhang = ("ATCGG", "TAGCTT")
merged.params.datatype = "pair3rad"
merged.params.phred_Qscore_offset = 43
merged.params.filter_adapters = 3
merged.params.mindepth_majrule = 3
merged.params.mindepth_statistical = 6
merged.params.max_barcode_mismatch = 1
merged.params.min_samples_locus = 10
merged.params.max_Ns_consens = 0.07
merged.params.max_Hs_consens = 0.07
merged.params.max_Indels_locus = 10
merged.params.output_formats = "psl"
merged.params

# %%
merged.run("234567", force=True, ipyclient=ipyclient)

# %%
merged.stats_dfs.s7_samples.sample_coverage < 5000
# Out:
# reference                    False
# acanthochiton_SLH_AL_0001    False
# acanthochiton_SLH_AL_0002    False
# acutilobus_SLH_AL_0003       False
# acutilobus_SLH_AL_0004       False
#                              ...
# viridis_SLH_AL_3047          False
# viridis_SLH_AL_3062          False
# watsonii_SLH_AL_3065         False
# wrightii_SLH_AL_3066         False
# wrightii_SLH_AL_3067         False
# Name: sample_coverage, Length: 231, dtype: bool

# %%
mask = merged.stats_dfs.s7_samples.sample_coverage < 4000
lose = merged.stats_dfs.s7_samples[mask].index.tolist()
lose
# Out:
# ['beet',
#  'blitoides_SLH_AL_0023',
#  'cannabinus_SLH_AL_0042',
#  'quinoa',
#  'unknown_SLH_AL_0055-contemp',
#  'unknown_SLH_AL_0062-contemp']

# %%
mask = merged.stats_dfs.s7_samples.sample_coverage > 4000
keep = merged.stats_dfs.s7_samples[mask].index.tolist()
keep = keep + ["quinoa","beet"]
new = merged.branch('Good_Samples_beet', subsamples=keep)

# %%
drop = merged.branch("225_samples_redo", subsamples=
                      [i for (i, j) in merged.samples.items() if j.stats_dfs.s7_samples > 4000], force=True, ipyclient=ipyclient)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-9be92c863fcc> in <module>
#       1 drop = merged.branch("225_samples", subsamples=
# ----> 2                       [i for (i, j) in merged.samples.items() if j.stats_dfs.s7_samples > 5000], force=True, ipyclient=ipyclient)
#
# <ipython-input-28-9be92c863fcc> in <listcomp>(.0)
#       1 drop = merged.branch("225_samples", subsamples=
# ----> 2                       [i for (i, j) in merged.samples.items() if j.stats_dfs.s7_samples > 5000], force=True, ipyclient=ipyclient)
#
# ~/miniconda3/lib/python3.7/site-packages/ipyrad/assemble/utils.py in __getattr__(self, name)
#      90             return self[name]
#      91         else:
# ---> 92             raise AttributeError("No such attribute: " + name)
#      93
#      94     def __setattr__(self, name, value):
#
# AttributeError: No such attribute: s7_samples

# %%
new.params
# Out:
# 0   assembly_name               Good_Samples_beet
# 1   project_dir                 ./ipyrad
# 2   raw_fastq_path              Merged: UGA_plate1, Columbia_plate1, Columbia_contemp, tuberculatus, quinoa, beet
# 3   barcodes_path               Merged: UGA_plate1, Columbia_plate1, Columbia_contemp, tuberculatus, quinoa, beet
# 4   sorted_fastq_path           Merged: UGA_plate1, Columbia_plate1, Columbia_contemp, tuberculatus, quinoa, beet
# 5   assembly_method             reference
# 6   reference_sequence          /moto/eaton/users/slh2181/reference/Ahypochondriacus_459_v2.0.fa
# 7   datatype                    pair3rad
# 8   restriction_overhang        ('ATCGG', 'TAGCTT')
# 9   max_low_qual_bases          5
# 10  phred_Qscore_offset         43
# 11  mindepth_statistical        6
# 12  mindepth_majrule            2
# 13  maxdepth                    10000
# 14  clust_threshold             0.85
# 15  max_barcode_mismatch        1
# 16  filter_adapters             3
# 17  filter_min_trim_len         35
# 18  max_alleles_consens         2
# 19  max_Ns_consens              0.07
# 20  max_Hs_consens              0.07
# 21  min_samples_locus           10
# 22  max_SNPs_locus              0.2
# 23  max_Indels_locus            10
# 24  max_shared_Hs_locus         0.5
# 25  trim_reads                  (0, 0, 0, 0)
# 26  trim_loci                   (0, 0, 0, 0)
# 27  output_formats              ['p', 's', 'l']
# 28  pop_assign_file
# 29  reference_as_filter

# %%
new.run("7", force=True, ipyclient=ipyclient)
# Out:
# Parallel connection | t103: 24 cores
# [####################] 100% 0:00:32 | applying filters     | s7 |
# [####################] 100% 0:22:52 | building arrays      | s7 |
# [####################] 100% 0:09:36 | writing conversions  | s7 |

# %%
new.stats
# Out:
#                                        state  reads_raw  reads_passed_filter  \
# acanthochiton_SLH_AL_0001                  6     445777               410836
# acanthochiton_SLH_AL_0002                  6     476100               452573
# acutilobus_SLH_AL_0003                     6    1040007               962934
# acutilobus_SLH_AL_0004                     6    1083567               996805
# albus_SLH_AL_0006                          6    1576377              1457412
# albus_SLH_AL_0009                          6     214972               202319
# albus_SLH_AL_0010                          6    1514048              1399687
# arenicola_SLH_AL_0012                      6     827082               785908
# arenicola_SLH_AL_0013                      6    1238127              1140023
# arenicola_SLH_AL_0015                      6    1447454              1377033
# arenicola_SLH_AL_0018                      6    2114914              1945273
# asplundii_SLH_AL_0019                      6    1127735              1036086
# australis_SLH_AL_0020                      6    1308151              1197630
# australis_SLH_AL_0021                      6    1153221              1061046
# beet                                       6    1136268              1090124
# unknown_SLH_AL_0028-contemp                6     777875               717223
# unknown_SLH_AL_0030-contemp                6     660172               607893
# unknown_SLH_AL_0032-contemp                6     623223               573421
# unknown_SLH_AL_0034-contemp                6    1102395              1022460
# unknown_SLH_AL_0036-contemp                6     673775               623628
# unknown_SLH_AL_0042-contemp                6     651199               599485
# unknown_SLH_AL_0048-contemp                6     459041               425263
# unknown_SLH_AL_0063-contemp                6     387144               360729
# unknown_SLH_AL_0064-contemp                6     847746               783116
# unknown_SLH_AL_0067-contemp                6     423407               391579
# unknown_SLH_AL_0069-contemp                6     795719               737561
# unknown_SLH_AL_0072-contemp                6     689025               634819
# unknown_SLH_AL_0077-contemp                6     323650               299801
# unknown_SLH_AL_0078-contemp                6     608900               564667
# unknown_SLH_AL_0079-contemp                6     568842               529130
# unknown_SLH_AL_0080-contemp                6     192964               178702
# unknown_SLH_AL_0083-contemp                6     805873               749144
# unknown_SLH_AL_0084-contemp                6     301090               278306
# unknown_SLH_AL_0086-contemp                6     148876               136470
# unknown_SLH_AL_0087-contemp                6     272270               251184
# unknown_SLH_AL_0088-contemp                6    1128493              1047992
# unknown_SLH_AL_0090-contemp                6     643992               593935
# unknown_SLH_AL_0092-contemp                6     571167               526594
# unknown_SLH_AL_0095-contemp                6    1138863              1048006
# unknown_SLH_AL_0096-contemp                6     563220               522102
# unknown_SLH_AL_0098-contemp                6     382594               355225
# unknown_SLH_AL_0100-contemp                6     752699               698511
# unknown_SLH_AL_0101-contemp                6    1074917               990708
# unknown_SLH_AL_0104-contemp                6     877438               811464
# unknown_SLH_AL_0105-contemp                6     631483               589118
# unknown_SLH_AL_0106-contemp                6     813260               754036
# unknown_SLH_AL_0108-contemp                6     419463               390475
# unknown_SLH_AL_149-contemp                 6    2048829              1940216
# unknown_SLH_AL_150-contemp                 6    2311941              2189051
# unknown_SLH_AL_194-contemp                 6    2615784              2469186
# unknown_SLH_AL_212-contemp                 6    2097758              1986672
# unknown_SLH_AL_239-contemp                 6    1560086              1477096
# viridis_SLH_AL_3047                        6     671502               609681
# viridis_SLH_AL_3062                        6     589406               537713
# watsonii_SLH_AL_3065                       6     241527               224111
# wrightii_SLH_AL_3066                       6     553404               514681
# wrightii_SLH_AL_3067                       6     507879               472117
#
#                                        refseq_mapped_reads  \
# acanthochiton_SLH_AL_0001                           331941
# acanthochiton_SLH_AL_0002                           390651
# acutilobus_SLH_AL_0003                              859479
# acutilobus_SLH_AL_0004                              895772
# albus_SLH_AL_0006                                  1163457
# albus_SLH_AL_0009                                   165771
# albus_SLH_AL_0010                                  1077122
# arenicola_SLH_AL_0012                               675520
# arenicola_SLH_AL_0013                               894749
# arenicola_SLH_AL_0015                              1178152
# arenicola_SLH_AL_0018                              1496909
# asplundii_SLH_AL_0019                               815930
# australis_SLH_AL_0020                               924737
# australis_SLH_AL_0021                               800892
# beet                                                 36043
# blitoides_SLH_AL_0028                              1101639
# blitum-blitum_SLH_AL_0029                           820392
# blitum-oleraceus_SLH_AL_0034                        952801
# tuberculatus_SLH_AL_3033                           1434659
# tuberculatus_SLH_AL_3034                            946196
# tuberculatus_SLH_AL_3035                           1237782
# tuberculatus_SLH_AL_3036                           1037392
# tuberculatus_SLH_AL_3037                            433998
# tuberculatus_SLH_AL_3038                            458103
# tuberculatus_SLH_AL_3039                            827445
# tuberculatus_SLH_AL_3041                           1664797
# tuberculatus_SLH_AL_3042                            591015
# tuberculatus_SLH_AL_3043                            318581
# tuberculatus_SLH_AL_3044                           1059006
# tuberculatus_SLH_AL_3045                            492116
# tuberculatus_SLH_AL_3046                            653105
# tucsonensis_SLH_AL_3068                            1083615
# unknown_SLH_AL_0002-contemp                         516289
# unknown_SLH_AL_0007_contemp                         310942
# unknown_SLH_AL_0008_contemp                         334390
# unknown_SLH_AL_0009-contemp                         168794
# unknown_SLH_AL_0010-contemp                         449787
# unknown_SLH_AL_0012-contemp                         492005
# unknown_SLH_AL_0013-contemp                         130567
# unknown_SLH_AL_0014-contemp                         388601
# unknown_SLH_AL_0018-contemp                         352693
# unknown_SLH_AL_0024-contemp                         837432
# unknown_SLH_AL_0025-contemp                         128950
# unknown_SLH_AL_0026-contemp                         995395
# unknown_SLH_AL_0027-contemp                         177013
# unknown_SLH_AL_0028-contemp                         564290
# unknown_SLH_AL_0030-contemp                         476397
# unknown_SLH_AL_0032-contemp                         437495
# unknown_SLH_AL_0034-contemp                         814160
# unknown_SLH_AL_0036-contemp                         482603
# unknown_SLH_AL_0042-contemp                         467095
# unknown_SLH_AL_0048-contemp                         339813
# unknown_SLH_AL_0063-contemp                         325378
# unknown_SLH_AL_0064-contemp                         721489
# unknown_SLH_AL_0067-contemp                         350304
# unknown_SLH_AL_0069-contemp                         659946
# unknown_SLH_AL_0072-contemp                         484740
# unknown_SLH_AL_0077-contemp                         270363
# unknown_SLH_AL_0078-contemp                         529934
# unknown_SLH_AL_0079-contemp                         484042
# unknown_SLH_AL_0080-contemp                         165302
# unknown_SLH_AL_0083-contemp                         699628
# unknown_SLH_AL_0084-contemp                         237305
# unknown_SLH_AL_0086-contemp                         122984
# unknown_SLH_AL_0087-contemp                         218613
# unknown_SLH_AL_0088-contemp                         991020
# unknown_SLH_AL_0090-contemp                         543705
# unknown_SLH_AL_0092-contemp                         481070
# unknown_SLH_AL_0095-contemp                         981637
# unknown_SLH_AL_0096-contemp                         485173
# unknown_SLH_AL_0098-contemp                         325341
# unknown_SLH_AL_0100-contemp                         647174
# unknown_SLH_AL_0101-contemp                         920318
# unknown_SLH_AL_0104-contemp                         673004
# unknown_SLH_AL_0105-contemp                         530600
# unknown_SLH_AL_0106-contemp                         702655
# unknown_SLH_AL_0108-contemp                         352336
# unknown_SLH_AL_149-contemp                         1810560
# unknown_SLH_AL_150-contemp                         2033401
# unknown_SLH_AL_194-contemp                         2252907
# unknown_SLH_AL_212-contemp                         1850395
# unknown_SLH_AL_239-contemp                         1352877
# viridis_SLH_AL_3047                                 473250
# viridis_SLH_AL_3062                                 405518
# watsonii_SLH_AL_3065                                190109
# wrightii_SLH_AL_3066                                464508
# wrightii_SLH_AL_3067                                420002
#
#                                        refseq_unmapped_reads  clusters_total  \
# acanthochiton_SLH_AL_0001                              78895           22978
# acanthochiton_SLH_AL_0002                              61922           22582
# acutilobus_SLH_AL_0003                                103455           32345
# acutilobus_SLH_AL_0004                                101033           31256
# albus_SLH_AL_0006                                     293955           27220
# albus_SLH_AL_0009                                      36548           17816
# albus_SLH_AL_0010                                     322565           29611
# arenicola_SLH_AL_0012                                 110388           27214
# arenicola_SLH_AL_0013                                 245274           34153
# arenicola_SLH_AL_0015                                 198881           32624
# arenicola_SLH_AL_0018                                 448364           39953
# asplundii_SLH_AL_0019                                 220156           22386
# australis_SLH_AL_0020                                 272893           33370
# australis_SLH_AL_0021                                 260154           34508
# beet                                                 1054081            3802
# blitoides_SLH_AL_0028                                 281432           26841
# blitum-blitum_SLH_AL_0029                             208579           22502
# blitum-oleraceus_SLH_AL_0034                          232978           22734
# blitum-pseudogracilis_SLH_AL_0037                     239800           21648
# californicus_SLH_AL_0039                              169907           23096
# cannabinus_SLH_AL_0040                                 31273           19272
# cannabinus_SLH_AL_0041                                272231           36265
# caudatus_SLH_AL_0102                                    5544           16225
# caudatus_SLH_AL_0110                                   15489           24221
# caudatus_SLH_AL_0116                                   20520           26272
# caudatus_SLH_AL_0322                                   49717           30238
# caudatus_SLH_AL_0540                                   40596           28781
# crassipes_SLH_AL_0599                                  84087           19956
# crassipes_SLH_AL_0600                                 169727           24010
# cruentus_SLH_AL_0679                                   50569           32573
# cruentus_SLH_AL_0699                                   47636           31499
# cruentus_SLH_AL_0728                                   43922           31520
# cruentus_SLH_AL_0804                                   58163           33299
# cruentus_SLH_AL_0832                                   57099           33791
# deflexus_SLH_AL_0951                                  144665           20389
# deflexus_SLH_AL_0952                                  131176           19401
# deflexus_SLH_AL_0953                                  160856           20465
# deflexus_SLH_AL_0954                                  127679           19818
# deflexus_SLH_AL_0955                                  105685           18853
# dubius_SLH_AL_0965                                    106577           41033
# dubius_SLH_AL_0979                                     85874           37082
# dubius_SLH_AL_0992                                     59689           32064
# fimbriatus_SLH_AL_0997                                 70465           26033
# fimbriatus_SLH_AL_0998                                123246           20842
# floridanus_SLH_AL_1000                                131481           26604
# graecizans-aschersonianus_SLH_AL_1009                 109569           17763
# graecizans-silvestris_SLH_AL_1013                     182096           23455
# graecizans-thellungianus_SLH_AL_1014                  159805           20470
# greggii_SLH_AL_1015                                   121973           24049
# greggii_SLH_AL_1016                                    87875           20105
# hybridus_SLH_AL_0001-restricted                        45035           31418
# hybridus_SLH_AL_1060                                   65859           35290
# hybridus_SLH_AL_1098                                   44496           30009
# hybridus_SLH_AL_1099                                   56133           32326
# hybridus_SLH_AL_1117                                   49775           31128
# hypochondriacus_SLH_AL_1178                             9400           24223
# hypochondriacus_SLH_AL_1197                            34149           34049
# hypochondriacus_SLH_AL_1264                            49031           36117
# hypochondriacus_SLH_AL_1285                            39179           34542
# hypochondriacus_SLH_AL_2282                            38673           35295
# hypochondriacus_SLH_AL_2436                            34642           32707
# unknown_SLH_AL_0026-contemp                            75316           35920
# unknown_SLH_AL_0027-contemp                            43395           17898
# unknown_SLH_AL_0028-contemp                           152933           29835
# unknown_SLH_AL_0030-contemp                           131496           28809
# unknown_SLH_AL_0032-contemp                           135926           31576
# unknown_SLH_AL_0034-contemp                           208300           32064
# unknown_SLH_AL_0036-contemp                           141025           30902
# unknown_SLH_AL_0042-contemp                           132390           29666
# unknown_SLH_AL_0048-contemp                            85450           23188
# unknown_SLH_AL_0063-contemp                            35351           24336
# unknown_SLH_AL_0064-contemp                            61627           33037
# unknown_SLH_AL_0067-contemp                            41275           24629
# unknown_SLH_AL_0069-contemp                            77615           30202
# unknown_SLH_AL_0072-contemp                           150079           28649
# ...
# unknown_SLH_AL_0104-contemp                       21716    0.011252
# unknown_SLH_AL_0105-contemp                       21410    0.002446
# unknown_SLH_AL_0106-contemp                       25774    0.001486
# unknown_SLH_AL_0108-contemp                       19900    0.001132
# unknown_SLH_AL_149-contemp                        31571    0.002302
# unknown_SLH_AL_150-contemp                        31584    0.002427
# unknown_SLH_AL_194-contemp                        29560    0.003900
# unknown_SLH_AL_212-contemp                        31389    0.002301
# unknown_SLH_AL_239-contemp                        26854    0.003352
# viridis_SLH_AL_3047                               15445    0.002267
# viridis_SLH_AL_3062                               15418    0.002323
# watsonii_SLH_AL_3065                              13600    0.007291
# wrightii_SLH_AL_3066                              20760    0.002465
# wrightii_SLH_AL_3067                              21047    0.002752
#
#                                        error_est  reads_consens
# acanthochiton_SLH_AL_0001               0.000835          15222
# acanthochiton_SLH_AL_0002               0.001283          16002
# acutilobus_SLH_AL_0003                  0.000631          25589
# acutilobus_SLH_AL_0004                  0.000610          24788
# albus_SLH_AL_0006                       0.000646          20356
# albus_SLH_AL_0009                       0.000884          11999
# albus_SLH_AL_0010                       0.000720          19757
# arenicola_SLH_AL_0012                   0.001184          19708
# arenicola_SLH_AL_0013                   0.000942          23208
# arenicola_SLH_AL_0015                   0.001251          23508
# arenicola_SLH_AL_0018                   0.001082          28402
# asplundii_SLH_AL_0019                   0.000633          16661
# australis_SLH_AL_0020                   0.001026          22740
# australis_SLH_AL_0021                   0.001120          22624
# beet                                    0.000291           2801
# blitoides_SLH_AL_0028                   0.000683          19878
# blitum-blitum_SLH_AL_0029               0.000635          16371
# blitum-oleraceus_SLH_AL_0034            0.000616          16629
# blitum-pseudogracilis_SLH_AL_0037       0.000641          16187
# californicus_SLH_AL_0039                0.000637          15374
# cannabinus_SLH_AL_0040                  0.001779          11151
# cannabinus_SLH_AL_0041                  0.001305          24736
# caudatus_SLH_AL_0102                    0.000710          10482
# caudatus_SLH_AL_0110                    0.000733          17706
# caudatus_SLH_AL_0116                    0.000659          18777
# caudatus_SLH_AL_0322                    0.000546          22974
# caudatus_SLH_AL_0540                    0.000574          21056
# crassipes_SLH_AL_0599                   0.000618          14148
# crassipes_SLH_AL_0600                   0.000593          17814
# cruentus_SLH_AL_0679                    0.000564          24679
# cruentus_SLH_AL_0699                    0.000609          24076
# unknown_SLH_AL_0092-contemp             0.000547          19809
# unknown_SLH_AL_0095-contemp             0.000556          29811
# unknown_SLH_AL_0096-contemp             0.000562          24117
# unknown_SLH_AL_0098-contemp             0.000621          19573
# unknown_SLH_AL_0100-contemp             0.000556          26039
# unknown_SLH_AL_0101-contemp             0.000571          28882
# unknown_SLH_AL_0104-contemp             0.000679          20819
# unknown_SLH_AL_0105-contemp             0.000553          20965
# unknown_SLH_AL_0106-contemp             0.000576          25407
# unknown_SLH_AL_0108-contemp             0.000563          19491
# unknown_SLH_AL_149-contemp              0.001099          31184
# unknown_SLH_AL_150-contemp              0.001101          31210
# unknown_SLH_AL_194-contemp              0.001091          28965
# unknown_SLH_AL_212-contemp              0.001069          31021
# unknown_SLH_AL_239-contemp              0.000989          26356
# viridis_SLH_AL_3047                     0.000643          14495
# viridis_SLH_AL_3062                     0.000657          14137
# watsonii_SLH_AL_3065                    0.000713          13128
# wrightii_SLH_AL_3066                    0.000629          20381
# wrightii_SLH_AL_3067                    0.000636          20570

# %% [markdown]
# ### Get a smaller dataset

# %%
merged = ip.load_json("/moto/eaton/users/slh2181/tuberculatus_plate/ipyrad/Good_Samples.json")
# Out:
# loading Assembly: Good_Samples
# from saved path: /moto/eaton/users/slh2181/tuberculatus_plate/ipyrad/Good_Samples.json

# %%
new2 = merged.branch('Less_data_Good')
new2.params.min_samples_locus = 20
new2.params.mindepth_statistical = 10
new2.params.mindepth_majrule = 4
new2.params
# Out:
# 0   assembly_name               Less_data_Good
# 1   project_dir                 ./ipyrad
# 2   raw_fastq_path              Merged: UGA_plate1, Columbia_plate1, Columbia_contemp, tuberculatus, quinoa
# 3   barcodes_path               Merged: UGA_plate1, Columbia_plate1, Columbia_contemp, tuberculatus, quinoa
# 4   sorted_fastq_path           Merged: UGA_plate1, Columbia_plate1, Columbia_contemp, tuberculatus, quinoa
# 5   assembly_method             reference
# 6   reference_sequence          /moto/eaton/users/slh2181/reference/Ahypochondriacus_459_v2.0.fa
# 7   datatype                    pair3rad
# 8   restriction_overhang        ('ATCGG', 'TAGCTT')
# 9   max_low_qual_bases          5
# 10  phred_Qscore_offset         43
# 11  mindepth_statistical        10
# 12  mindepth_majrule            4
# 13  maxdepth                    10000
# 14  clust_threshold             0.85
# 15  max_barcode_mismatch        1
# 16  filter_adapters             3
# 17  filter_min_trim_len         35
# 18  max_alleles_consens         2
# 19  max_Ns_consens              0.07
# 20  max_Hs_consens              0.07
# 21  min_samples_locus           20
# 22  max_SNPs_locus              0.2
# 23  max_Indels_locus            10
# 24  max_shared_Hs_locus         0.5
# 25  trim_reads                  (0, 0, 0, 0)
# 26  trim_loci                   (0, 0, 0, 0)
# 27  output_formats              ['p', 's', 'l']
# 28  pop_assign_file
# 29  reference_as_filter

# %%
#The second step is the same for all.  This takes a long time
new2.run("4567", force=True, auto=True)
# Out:
# Parallel connection | t025: 24 cores
# [####################] 100% 0:13:44 | inferring [H, E]     | s4 |
# [####################] 100% 0:00:19 | calculating depths   | s5 |
# [####################] 100% 0:00:33 | chunking clusters    | s5 |
# [####################] 100% 0:38:12 | consens calling      | s5 |
# [####################] 100% 0:02:56 | indexing alleles     | s5 |
# [####################] 100% 0:00:37 | concatenating bams   | s6 |
# [####################] 100% 0:00:11 | fetching regions     | s6 |
# [####################] 100% 0:00:20 | building database    | s6 |
# [####################] 100% 0:00:27 | applying filters     | s7 |
# [####################] 100% 0:13:10 | building arrays      | s7 |
# [####################] 100% 0:05:16 | writing conversions  | s7 |
